# %%
a=10
print(a)
# Out:
# 10

# %%
with open('notes.txt', 'r') as file:
    content = file.read()
    print(content)

with open('notes.txt', 'w') as file:
    file.write("The old content is overwritten with this new content.\n This is the new content.")
with open('notes.txt', 'a') as file:
    file.write("\nThis line is appended to the existing content.")

with open('notes.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# This is a sample file created for testing File handling
# The old content is overwritten with this new content.
#  This is the new content.
# This line is appended to the existing content.

# %%
file=open('notes.txt', 'r')
content=file.read()
print(content)
file.close()
